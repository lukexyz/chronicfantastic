# %%
# default_exp core

# %% [markdown]
# # 🔴 Setup Room
# **1.** Create `VDO.Ninja` room (director)
# **2.** Create joiner URL

# %% [markdown]
# # 1. `Create` Room
# https://vdo.ninja/?director=chronicfantastic2000
#  Director properties
# * ✅ Ask for display name `&l`
# * ✅ Show display names `&d`
# * ✅ Mini self-preview `&mini`
# * ✅
# * ✅
# * ✅

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# # 2. `Join URL` using OBS URL params
# Docs: https://docs.vdo.ninja/getting-started/the-power-of-the-url-parameter

# %% [markdown]
# 1. Create room as director
# - Guests can see director, but not other guests videos
# - Director will be performing as well

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://vdo.ninja/?room=chronicfantastic2000&broadcast&hash=31d6&m&g=0&l&sl&view=

# %%
roomname = 'chronicfantastic2000'
username = 'luke'
password = ''

baseurl = f'https://vdo.ninja/?room={roomname}&broadcast&l={username}&m&ad&sl&view&push=JibZgQM'

# %%
baseurl
# Out:
# 'https://vdo.ninja/?room=chronicfantastic2000&broadcast&l=luke&m&ad&sl&view&push=JibZgQM'
