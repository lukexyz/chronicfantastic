# %%
# default_exp core

# %% [markdown]
# # OBS Url params
# https://docs.vdo.ninja/getting-started/the-power-of-the-url-parameter

# %% [markdown]
# 1. Create room as director
# - Guests can see director, but not other guests videos
# - Director will be performing as well

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://vdo.ninja/?room=chronicfantastic2000&broadcast&hash=31d6&m&g=0&l&sl&view=

# %%
roomname = 'chronicfantastic2000'
username = 'luke'
password = ''

baseurl = f'https://vdo.ninja/?room={roomname}&broadcast&l={username}&m&vd&ad&view&push=JibZgQM'

# %%
baseurl
# Out:
# 'https://vdo.ninja/?room=chronicfantastic2000&broadcast&l=luke&m&vd&ad&view&push=JibZgQM'
